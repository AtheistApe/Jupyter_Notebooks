# %%
plot(rnorm(1000))
# Out:
# plot without title

# %%
rnorm(15)
# Out:
#  [1]  0.7894482 -0.3505058 -1.2646709  0.2286136 -1.7024141 -0.5476538
#  [7] -1.7758297  0.4383535 -1.4404505  0.4459929  1.0400986 -0.8955473
# [13] -0.5894613  0.9532757  1.2944623

# %%
x <- 2

# %%
sqrt(x**2)
# Out:
# [1] 2

# %%
weight <- c(60, 72, 58, 77, 50, 71)

# %%
weight
# Out:
# [1] 60 72 58 77 50 71

# %%
x = 4

# %%
x^2
# Out:
# [1] 16

# %%
weight^2 + 4*weight
# Out:
# [1] 3840 5472 3596 6237 2700 5325

# %%
mean(weight)
# Out:
# [1] 64.66667

# %%
median(weight)
# Out:
# [1] 65.5

# %%
plot(weight)
# Out:
# plot without title

# %%
install.packages('ISwR',repos="http://cran.rstudio.com/")
# Out:
# Installing package into ‘/home/gary/R/x86_64-pc-linux-gnu-library/3.6’
# (as ‘lib’ is unspecified)

# %%
search()
# Out:
#  [1] ".GlobalEnv"        "jupyter:irkernel"  "package:stats"
#  [4] "package:graphics"  "package:grDevices" "package:utils"
#  [7] "package:datasets"  "package:methods"   "Autoloads"
# [10] "package:base"

# %%
library(ISwR)

# %%
search()
# Out:
#  [1] ".GlobalEnv"        "package:ISwR"      "jupyter:irkernel"
#  [4] "package:stats"     "package:graphics"  "package:grDevices"
#  [7] "package:utils"     "package:datasets"  "package:methods"
# [10] "Autoloads"         "package:base"

# %%
weight
# Out:
# [1] 60 72 58 77 50 71

# %%
height = c(1.75, 1.80, 1.65, 1.90, 1.74, 1.91)

# %%
bmi = weight/height^2
bmi
# Out:
# [1] 19.59184 22.22222 21.30395 21.32964 16.51473 19.46219

# %%
sum(weight)
# Out:
# [1] 388

# %%
length(weight)
# Out:
# [1] 6

# %%
sum(weight)/length(weight)
# Out:
# [1] 64.66667

# %%
xbar = sum(weight)/length(weight)

# %%
weight - xbar
# Out:
# [1]  -4.666667   7.333333  -6.666667  12.333333 -14.666667   6.333333

# %%
(weight - xbar)^2
# Out:
# [1]  21.77778  53.77778  44.44444 152.11111 215.11111  40.11111

# %%
sum((weight - xbar)^2)
# Out:
# [1] 527.3333

# %%
sqrt(sum((weight - xbar)^2))
# Out:
# [1] 22.96374

# %%
mean(weight)
# Out:
# [1] 64.66667

# %%
sd(weight)
# Out:
# [1] 10.2697
