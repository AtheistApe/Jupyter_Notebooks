# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure(figsize=(6,8))
ax = fig.gca(projection='3d')

t1 = np.linspace(-1.1, 0.1, 100)
t2 = np.linspace(2.9, 4.1, 100)

x1 = t1
y1 = 1 - t1
z1 = 3 + t1**2

x2 = 3 - t2
y2 = t2 - 2
z2 = t2

ax.plot(x1, y1, z1, label='parametric curve')
ax.plot(x2, y2, z2)
ax.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.5">

# %%
from scipy.optimize import fsolve

from ipywidgets import interact, interactive, fixed, interact_manual
from ipykernel.pylab.backend_inline import flush_figures

import ipywidgets as widgets

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure(figsize=(8,5))
ax = fig.gca()


m = 5.0
k = 1
g = 9.8
v0 = 100.0
theta = 45.0*np.pi/180.0

def myplot(k,v0,theta):
    
    def func(t):
        return (v0*np.sin(theta) + m*g/k)*(1 - np.exp(-k*t/m)) - g*t

    tf = fsolve(func, 20)
    print(tf)
    t = np.linspace(0, tf, 100)
    x = m/k*v0*np.cos(theta)*(1 - np.exp(-k*t/m))
    y = m/k*((v0*np.sin(theta)+m*g/k)*(1 - np.exp(-k*t/m)) - g*t)
    ax.plot(x, y)
#     plt.show()
#     fig.canvas.draw()
#     flush_figures()

interactive_plot = interactive(myplot, k=(0.1, 2.0), v0=(10, 200), theta=(0, 90*np.pi/180))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# <img src="data:image/png;base64,..." width="799.3333333333334">
# interactive(children=(FloatSlider(value=1.05, description='k', max=2.0, min=0.1), IntSlider(value=105, descrip…

# %%
from scipy.optimize import fsolve

from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# x = np.linspace(0, 2 * np.pi)
# fig = plt.figure()
# ax = fig.add_subplot(1, 1, 1)
# line, = ax.plot(x, np.sin(x))


m = 5.0
k = 1
g = 9.8
v0 = 100.0
theta = 45.0*np.pi/180.0

def myplot(k=1,v0=100,theta=45*np.pi/180):
    
    def func(t):
        return (v0*np.sin(theta) + m*g/k)*(1 - np.exp(-k*t/m)) - g*t

    tf = fsolve(func, 20)
    print(tf)
    
    t = np.linspace(0, tf, 100)
    
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    
    x = m/k*v0*np.cos(theta)*(1 - np.exp(-k*t/m))
    y = m/k*((v0*np.sin(theta)+m*g/k)*(1 - np.exp(-k*t/m)) - g*t)
    
    line, = ax.plot(x, y)
    line.set_ydata(y)
    fig.canvas.draw()
#     plt.show()


# def update(w = 1.0):
# def myplot(k=0.01, v0=80.0, theta=45.0*np.pi/180.0):
#     line.set_ydata(y)
#     fig.canvas.draw()

output = interactive_plot.children[-1]
output.layout.height = '500px'
interact(myplot);
# Out:
# interactive(children=(IntSlider(value=1, description='k', max=3, min=-1), IntSlider(value=100, description='v0…
