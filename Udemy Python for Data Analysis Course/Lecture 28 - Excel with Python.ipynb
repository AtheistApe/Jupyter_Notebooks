# %%
import sys
sys.path.append('/Users/gary/anaconda/lib/python2.7/site-packages')

# %%
import pandas as pd

# %%
# pip install xird
# pip install openpyxl

# %%
xlsfile = pd.ExcelFile('Lec_28_test.xlsx')

# %%
dframe = xlsfile.parse('Sheet1')

# %%
dframe
# Out:
#    This is a test  Unnamed: 1  Unnamed: 2
# 0              23        6678         456
# 1             234         678         456
# 2             234           7         345
# 3              34          56         234
# 4               5         456        4365

# %%
m253_scores = pd.ExcelFile('CSM_M253Church_totals122513.xlsx')

# %%
m253_dframe = m253_scores.parse('Sheet1')
m253_dframe
# Out:
#                              3D_Coord_Systems  \
# NaN          NaN                            7
#              NaN                          NaN
# Argamaso     Eric J.                        7
# Artache      Alex M.                        7
# Ayllon       Anthony P.                     6
# Bayersdorfer Rachel B.                      7
# Carias       Marcela C.                     7
# Choy         Kaitlin                        7
# Connors      Jennifer E.                    7
#              Ryan M.                        7
# Denton       Nicholas S.                    7
# Diehl        Andrew W.                      7
# Ford         Mark R.                        7
# Frederick    Chloe                          7
# Hix          Holden C.                      7
# Howland      Abraham M.                     7
# Kwak         Ashley S.                      7
# Liang        Bryan J.                       7
# Lu           Alan G.                        7
# ...

# %% [markdown]
# $$
# f(x)=
# \begin{cases}
# \dfrac{1}{2(x-1)}, & x>1 \\[1ex]
# \dfrac{\Gamma(x)}{2^{x-1}}, & 0<x<1
# \end{cases}
# $$
