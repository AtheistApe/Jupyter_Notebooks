# %%
import pandas
import numpy as np

# %%
data = pandas.read_csv("weather_year.csv")

# %%
data.head()
# Out:
#          EDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2012-3-10                56                 40                24
# 1  2012-3-11                67                 49                30
# 2  2012-3-12                71                 62                53
# 3  2012-3-13                76                 63                50
# 4  2012-3-14                80                 62                44
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              24              20             16            74
# 1              43              31             24            78
# 2              59              55             43            90
# 3              57              53             47            93
# 4              58              52             43            93
#
#     Mean Humidity   Min Humidity       ...         Max VisibilityMiles  \
# 0              50             26       ...                          10
# ...

# %%
data.tail()
# Out:
#            EDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 361   2013-3-6                32                 31                29
# 362   2013-3-7                36                 32                28
# 363   2013-3-8                47                 35                23
# 364   2013-3-9                56                 45                33
# 365  2013-3-10                60                 52                50
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 361              27              26             25            92
# 362              27              25             22            85
# 363              27              24             21            88
# 364              32              29             23            75
# 365              37              34             32            54
#
#       Mean Humidity   Min Humidity       ...         Max VisibilityMiles  \
# 361              85             78       ...                          10
# ...

# %%
data.sample(5)
# Out:
#             EDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 129   2012-7-17                98                 87                75
# 123   2012-7-11                95                 79                63
# 220  2012-10-16                69                 52                35
# 352   2013-2-25                47                 36                24
# 248  2012-11-13                43                 34                24
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 129              73              70             68            94
# 123              60              56             53            81
# 220              48              42             35           100
# 352              26              23             21            88
# 248              24              22             21            85
#
#       Mean Humidity   Min Humidity       ...         Max VisibilityMiles  \
# ...

# %%
data.dtypes.describe()
# Out:
# count        23
# unique        3
# top       int64
# freq         16
# dtype: object

# %%
len(data)
# Out:
# 366

# %%
len(data.columns)
# Out:
# 23

# %%
data[["EDT","Mean TemperatureF"]]
# Out:
#            EDT  Mean TemperatureF
# 0    2012-3-10                 40
# 1    2012-3-11                 49
# 2    2012-3-12                 62
# 3    2012-3-13                 63
# 4    2012-3-14                 62
# 5    2012-3-15                 69
# 6    2012-3-16                 64
# 7    2012-3-17                 62
# 8    2012-3-18                 70
# 9    2012-3-19                 72
# 10   2012-3-20                 71
# 11   2012-3-21                 71
# 12   2012-3-22                 69
# 13   2012-3-23                 64
# 14   2012-3-24                 56
# 15   2012-3-25                 61
# 16   2012-3-26                 54
# 17   2012-3-27                 54
# 18   2012-3-28                 64
# 19   2012-3-29                 58
# 20   2012-3-30                 66
# 21   2012-3-31                 58
# 22    2012-4-1                 64
# 23    2012-4-2                 62
# 24    2012-4-3                 69
# 25    2012-4-4                 62
# ...

# %%
data.EDT.head(10)
# Out:
# 0    2012-3-10
# 1    2012-3-11
# 2    2012-3-12
# 3    2012-3-13
# 4    2012-3-14
# 5    2012-3-15
# 6    2012-3-16
# 7    2012-3-17
# 8    2012-3-18
# 9    2012-3-19
# Name: EDT, dtype: object

# %%
data["Mean TemperatureF"].tail(10)
# Out:
# 356    34
# 357    30
# 358    28
# 359    30
# 360    35
# 361    31
# 362    32
# 363    35
# 364    45
# 365    52
# Name: Mean TemperatureF, dtype: int64

# %%
data.columns
# Out:
# Index([u'EDT', u'Max TemperatureF', u'Mean TemperatureF', u'Min TemperatureF',
#        u'Max Dew PointF', u'MeanDew PointF', u'Min DewpointF', u'Max Humidity',
#        u' Mean Humidity', u' Min Humidity', u' Max Sea Level PressureIn',
#        u' Mean Sea Level PressureIn', u' Min Sea Level PressureIn',
#        u' Max VisibilityMiles', u' Mean VisibilityMiles',
#        u' Min VisibilityMiles', u' Max Wind SpeedMPH', u' Mean Wind SpeedMPH',
#        u' Max Gust SpeedMPH', u'PrecipitationIn', u' CloudCover', u' Events',
#        u' WindDirDegrees'],
#       dtype='object')

# %%
for str in data.columns:
    print str
# Out:
# EDT
# Max TemperatureF
# Mean TemperatureF
# Min TemperatureF
# Max Dew PointF
# MeanDew PointF
# Min DewpointF
# Max Humidity
#  Mean Humidity
#  Min Humidity
#  Max Sea Level PressureIn
#  Mean Sea Level PressureIn
#  Min Sea Level PressureIn
#  Max VisibilityMiles
#  Mean VisibilityMiles
#  Min VisibilityMiles
#  Max Wind SpeedMPH
#  Mean Wind SpeedMPH
#  Max Gust SpeedMPH
# PrecipitationIn
#  CloudCover
#  Events
#  WindDirDegrees

# %%
temp_data = data.columns

# %%
temp_data
# Out:
# Index([u'EDT', u'Max TemperatureF', u'Mean TemperatureF', u'Min TemperatureF',
#        u'Max Dew PointF', u'MeanDew PointF', u'Min DewpointF', u'Max Humidity',
#        u' Mean Humidity', u' Min Humidity', u' Max Sea Level PressureIn',
#        u' Mean Sea Level PressureIn', u' Min Sea Level PressureIn',
#        u' Max VisibilityMiles', u' Mean VisibilityMiles',
#        u' Min VisibilityMiles', u' Max Wind SpeedMPH', u' Mean Wind SpeedMPH',
#        u' Max Gust SpeedMPH', u'PrecipitationIn', u' CloudCover', u' Events',
#        u' WindDirDegrees'],
#       dtype='object')

# %%
import re
patterns = [ 'this', 'that' ]
text = 'Does this text match the pattern?'

for pattern in patterns:
    print 'Looking for "%s" in "%s" ->' % (pattern, text),

    if re.search(pattern,  text):
        print 'found a match!'
    else:
        print 'no match'
# Out:
# Looking for "this" in "Does this text match the pattern?" -> found a match!
# Looking for "that" in "Does this text match the pattern?" -> no match

# %%
# Pre-compile the patterns
regexes = [ re.compile(p) for p in [ 'this',
                                     'that',
                                     ]
            ]
text = 'Does this text match the pattern?'

for regex in regexes:
    print 'Looking for "%s" in "%s" ->' % (regex.pattern, text),

    if regex.search(text):
        print 'found a match!'
    else:
        print 'no match'
# Out:
# Looking for "this" in "Does this text match the pattern?" -> found a match!
# Looking for "that" in "Does this text match the pattern?" -> no match

# %%
bold = re.compile(r'\*{2}(.*?)\*{2}', re.UNICODE)

text = 'Make this **bold**.  This **too**.'

print 'Text:', text
print 'Bold:', bold.sub(r'<b>\1</b>', text)
# Out:
# Text: Make this **bold**.  This **too**.
# Bold: Make this <b>bold</b>.  This <b>too</b>.

# %%
for expr in temp_data:
    re.sub(r'(^[A-Za-z].*\s)Temp.*',r'\1_temp',expr)

# %%
temp_data
# Out:
# Index([u'EDT', u'Max TemperatureF', u'Mean TemperatureF', u'Min TemperatureF',
#        u'Max Dew PointF', u'MeanDew PointF', u'Min DewpointF', u'Max Humidity',
#        u' Mean Humidity', u' Min Humidity', u' Max Sea Level PressureIn',
#        u' Mean Sea Level PressureIn', u' Min Sea Level PressureIn',
#        u' Max VisibilityMiles', u' Mean VisibilityMiles',
#        u' Min VisibilityMiles', u' Max Wind SpeedMPH', u' Mean Wind SpeedMPH',
#        u' Max Gust SpeedMPH', u'PrecipitationIn', u' CloudCover', u' Events',
#        u' WindDirDegrees'],
#       dtype='object')

# %%
tdata = []
for expr in temp_data:
    tdata.append(re.sub('Temperature','temp', expr))

# %%
tdata
# Out:
# ['EDT',
#  'Max tempF',
#  'Mean tempF',
#  'Min tempF',
#  'Max Dew PointF',
#  'MeanDew PointF',
#  'Min DewpointF',
#  'Max Humidity',
#  ' Mean Humidity',
#  ' Min Humidity',
#  ' Max Sea Level PressureIn',
#  ' Mean Sea Level PressureIn',
#  ' Min Sea Level PressureIn',
#  ' Max VisibilityMiles',
#  ' Mean VisibilityMiles',
#  ' Min VisibilityMiles',
#  ' Max Wind SpeedMPH',
#  ' Mean Wind SpeedMPH',
#  ' Max Gust SpeedMPH',
#  'PrecipitationIn',
#  ' CloudCover',
#  ' Events',
#  ' WindDirDegrees']

# %%
re.sub('Temperature', 'temp', 'Max_Temperature')
# Out:
# 'Max_temp'
